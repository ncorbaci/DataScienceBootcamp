# %%
#1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


pop1=[]
pop2=[]
for i in range(50):
    populasyon = np.random.normal(10, 1, 1000)
    pop1.append(populasyon.mean())

for i in range(1000):
    populasyon2 = np.random.normal(10, 5, 1000)
    pop2.append(populasyon2.mean())
    
np.array(pop1).mean()
np.array(pop2).mean()
# Out:
# 10.003348783110564

# %%
plt.figure(figsize=(8,5))
plt.hist(pop1, alpha=0.9, label='Popülasyon 1') 
plt.hist(pop2, alpha=0.3, label='Popülasyon 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
örneklem = []
örneklem_ortalamaları = []
for atış_sayısı in range(1,2000):
    atış = np.random.randint(low=1,high=3, size=1)[0]
    örneklem.append(atış)
    örneklem_ortalamaları.append(np.mean(örneklem))

# %%
print(örneklem[0:10])
print(örneklem_ortalamaları[0:10])
# Out:
# [1, 1, 2, 1, 2, 1, 2, 1, 1, 1]
# [1.0, 1.0, 1.3333333333333333, 1.25, 1.4, 1.3333333333333333, 1.4285714285714286, 1.375, 1.3333333333333333, 1.3]

# %%
def orneklem_plotla(örneklem_ortalaması,orneklem_sayisi, subplot_no):
    baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
    eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
    plt.subplot(subplot_no)
    plt.hlines(1.5, 0, orneklem_sayisi, colors= 'r' )
    plt.plot(örneklem_ortalaması[0:orneklem_sayisi])
    plt.ylim((1,2))
    plt.title("Örneklem Sayısı = {}".format(orneklem_sayisi), fontdict = baslik_font)
    plt.xlabel("Örneklem Sayısı", fontdict = eksen_font)
    plt.ylabel("Örneklem Ortalaması", fontdict = eksen_font)
    return plt

# %%
plt.figure(figsize=(15,3), dpi=100)
orneklem_plotla(örneklem_ortalamaları,100, 131) 
# 131 --> 1 satır ve 3 sütunluk subplot, 1.subplot
orneklem_plotla(örneklem_ortalamaları, 500, 132)
orneklem_plotla(örneklem_ortalamaları, 2000, 133)
plt.show()

# %%
popX1=[]
for i in range(1):
    popX1.append(1)

for i in range(3):
    popX1.append(2)
    
np.random.choice(popX1)  

örneklem = []
örneklem_ortalamaları = []
for atış_sayısı in range(1,2000):
    atış = np.random.choice(popX1)
    örneklem.append(atış)
    örneklem_ortalamaları.append(np.mean(örneklem))

# %%
print(örneklem[0:10])
print(örneklem_ortalamaları[0:10])
# Out:
# [1, 2, 1, 2, 2, 2, 2, 2, 1, 2]
# [1.0, 1.5, 1.3333333333333333, 1.5, 1.6, 1.6666666666666667, 1.7142857142857142, 1.75, 1.6666666666666667, 1.7]

# %%
def orneklem_plotla(örneklem_ortalaması,orneklem_sayisi, subplot_no):
    baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
    eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
    plt.subplot(subplot_no)
    plt.hlines(1.75, 0, orneklem_sayisi, colors= 'r' )
    plt.plot(örneklem_ortalaması[0:orneklem_sayisi])
    plt.ylim((0,3))
    plt.title("Örneklem Sayısı = {}".format(orneklem_sayisi), fontdict = baslik_font)
    plt.xlabel("Örneklem Sayısı", fontdict = eksen_font)
    plt.ylabel("Örneklem Ortalaması", fontdict = eksen_font)
    return plt

# %%
plt.figure(figsize=(15,3), dpi=100)
orneklem_plotla(örneklem_ortalamaları,100, 131) 
# 131 --> 1 satır ve 3 sütunluk subplot, 1.subplot
orneklem_plotla(örneklem_ortalamaları, 500, 132)
orneklem_plotla(örneklem_ortalamaları, 2000, 133)
plt.show()
